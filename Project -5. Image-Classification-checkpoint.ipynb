# %% [markdown]
# **Problem Statement**
#
# You are a data-scientist of a global company. As a data-scientist you have to build an image classification model
# to classify 2 categories of image samely cat and dogs.

# %% [markdown]
# **Dataset Information**
#
# Cats and Dogs dataset contains 1000 images out of which 500 images are of cat and same for the dog.

# %% [markdown]
# **Importing the Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %% [markdown]
# **Loading the Image Data**

# %%
DIRECTORY = r"C:\Users\irsmj\CatsandDogs_Dataset"
CATEGORY = ['cat','dog']

# %%
Image_Width=128
Image_Height=128
Image_Size=(Image_Width,Image_Height)
Image_Channels=3

# %%
input_dir=r"C:\Users\irsmj\CatsandDogs_Dataset"

# %%
categories = ["Cat","Dog"]
for category in categories:
    for file in os.listdir(os.path.join(input_dir,category)):
        img_path=os.path.join(input_dir,category,file)
        print(img_path)
# Out:
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.1.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.10.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.100.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.101.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.102.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.103.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.104.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.105.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.106.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.107.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.108.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.109.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.11.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.110.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.111.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.112.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.113.jpg
# C:\Users\irsmj\CatsandDogs_Dataset\Cat\cat.114.jpg
# ...

# %% [markdown]
# **Displaying the Image**

# %%
Image.open("CatsandDogs_Dataset\Cat\cat.14.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x267>

# %%
Image.open("CatsandDogs_Dataset\Dog\dog.1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=327x499>

# %% [markdown]
# **Image conversion to array**
#
# **A) Converting the image to numpy array**

# %%
img_path=r"C:\Users\irsmj\CatsandDogs_Dataset\Dog\dog.11.jpg"
img=imread(img_path)
print(img)
# Out:
# [[[147 158 141]
#   [114 125 108]
#   [117 128 111]
#   ...
#   [185 210 155]
#   [157 177 128]
#   [214 231 187]]
#
#  [[118 129 112]
#   [ 77  88  71]
#   [ 68  80  60]
#   ...
#   [160 185 128]
#   [135 155 104]
#   [185 202 157]]
#
#  [[105 117  95]
#   [ 62  74  52]
#   [ 48  60  38]
#   ...
#   [152 176 116]
#   [147 168 112]
#   [174 192 142]]
#
#  ...
#
#  [[ 89 107  95]
#   [ 41  59  47]
#   [ 34  50  40]
#   ...
#   [146 145 127]
#   [137 134 119]
#   [208 202 190]]
#
#  [[106 124 110]
#   [ 64  82  68]
#   [ 45  61  50]
#   ...
#   [ 95  94  76]
#   [102  99  84]
#   [191 185 173]]
#
#  [[103 121 105]
#   [ 72  90  74]
#   [ 48  65  49]
#   ...
#   [ 83  82  64]
#   [ 96  93  78]
#   [186 180 168]]]

# %% [markdown]
# B) **Resizing and flattening the numpy array.**

# %%
img=resize(img,(15,15))
img=img.flatten()
img
# Out:
# array([0.35750754, 0.42811684, 0.30542773, 0.36000623, 0.46114421,
#        0.30768016, 0.3996312 , 0.50188641, 0.31698443, 0.49052677,
#        0.56526165, 0.37832755, 0.55742269, 0.61701464, 0.3927447 ,
#        0.60655542, 0.65379092, 0.45380135, 0.5377343 , 0.62249142,
#        0.40251994, 0.5429099 , 0.63175736, 0.37346161, 0.59009319,
#        0.65982557, 0.40416496, 0.55876166, 0.63809322, 0.3843586 ,
#        0.57574677, 0.6250354 , 0.43695826, 0.52172323, 0.58362947,
#        0.43065292, 0.55590532, 0.64398244, 0.43350559, 0.55154889,
#        0.6477899 , 0.40468181, 0.5468751 , 0.64578551, 0.41449954,
#        0.35080078, 0.45586435, 0.2847931 , 0.39325936, 0.49194059,
#        0.31310846, 0.49000489, 0.55515277, 0.39269861, 0.47726674,
#        0.52202286, 0.38589534, 0.4411387 , 0.46855904, 0.32844286,
#        0.49857687, 0.48678899, 0.36661262, 0.41368768, 0.49912366,
#        0.3334502 , 0.37746658, 0.46952382, 0.30516982, 0.36445918,
# ...

# %% [markdown]
# **Image conversion to array**

# %%
data=[]
labels=[]

# %%
for category_idx,category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir,category)):
        img_path=os.path.join(input_dir,category,file)
        img=imread(img_path)
        img=resize(img,(15,15))
        labels=np.asarray(labels)
        data=np.asarray(data)

# %% [markdown]
# **Logistic Regression**
#
# Accuracy obtained by logistic regression is 54 percent

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0.23,shuffle=True,stratify=labels)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr=LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Logistic Regression model accuracy (in %):", acc*100)

# %% [markdown]
# **Decision Tree**
#
# Accuracy obtained by decision tree model is 56 percent.

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
accuray_score(y_test,y_pred)

# %% [markdown]
# **Random Forest**
#
# Accuracy obtained by random forest model is 64.5 percent.

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=1000)
rfc.fit(x_train,y_test)
acc=accuracy_score(y_test,y_pred)
print(acc)

# %% [markdown]
# **Hyperparameter Tuning - Random Forest**
#
# Accuracy obtained by random forest model is 65.5 percent.
